# %% [markdown]
# <a href="https://colab.research.google.com/github/SSGR/Exploratory-Data-Analysis-of-Maharashtra-census-data-Using-Pandas/blob/main/MHA_population_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Maharashtra Census Data Exploratory Analysis**

# %% [markdown]
# **Importing all the essential Library for Analysis**

# %%
import os.path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# **Importing Dataset for Analysis**

# %%
data_path = "MHA Population Report.csv"
if os.path.exists(data_path):
  df = pd.read_csv(data_path)
else:
  print("File Not Found")

# %% [markdown]
# **Showing Top rows of dataset**

# %%
df.head()
# Out:
#    Census Year    District Taluka Town/Village  No. of households  \
# 0         2011  AHMADNAGAR  AKOLA   ABIT KHIND                201
# 1         2011  AHMADNAGAR  AKOLA         AGAR                 37
# 2         2011  AHMADNAGAR  AKOLA  AGASTINAGAR                357
# 3         2011  AHMADNAGAR  AKOLA        AKOLA               3861
# 4         2011  AHMADNAGAR  AKOLA        AMBAD                529
#
#    Total population  Total male population  Total female population  \
# 0               732                    359                      373
# 1               247                    162                       85
# 2              1536                    799                      737
# 3             18278                   9381                     8897
# 4              2590                   1352                     1238
#
#    Total 0 to 6 year children  Male 0 to 6 year children  ...  \
# 0                          73                         36  ...
# 1                          27                         15  ...
# 2                         178                         97  ...
# 3                        2066                       1101  ...
# 4                         333                        189  ...
#
#    Female literates  Total iliterates  Male iliterates  Female iliterates  \
# 0               175             313.0            115.0              198.0
# 1                53              58.0             26.0               32.0
# 2               467             462.0            192.0              270.0
# 3              6437            4400.0           1940.0             2460.0
# 4               743             845.0            350.0              495.0
#
#    Total main workers  Male main workers  Female main workers  \
# 0                 424                204                  220
# 1                 106                 58                   48
# 2                 787                439                  348
# 3                6688               4599                 2089
# 4                1491                763                  728
#
#    Total non workers  Male non workers  Female non workers
# 0                285               143                 142
# 1                140               103                  37
# 2                681               332                 349
# 3              10937              4422                6515
# 4               1083               580                 503
#
# [5 rows x 29 columns]

# %% [markdown]
# **Display Basic Information of Dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132315 entries, 0 to 132314
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Census Year                  132315 non-null  int64
#  1   District                     132315 non-null  object
#  2   Taluka                       132299 non-null  object
#  3   Town/Village                 131279 non-null  object
#  4   No. of households            132315 non-null  int64
#  5   Total population             132315 non-null  int64
#  6   Total male population        132315 non-null  int64
#  7   Total female population      132315 non-null  int64
#  8   Total 0 to 6 year children   132315 non-null  int64
#  9   Male 0 to 6 year children    132315 non-null  int64
#  10  Female 0 to 6 year children  132315 non-null  int64
#  11  Total SC population          132315 non-null  int64
#  12  Male SC population           132315 non-null  int64
#  13  Female SC population         132315 non-null  int64
#  14  Total ST population          132315 non-null  int64
#  15  Male ST population           132315 non-null  int64
#  16  Female ST population         132315 non-null  int64
#  17  Total literates              132315 non-null  int64
#  18  Male literates               132315 non-null  int64
#  19  Female literates             132315 non-null  int64
#  20  Total iliterates             82968 non-null   float64
#  21  Male iliterates              82968 non-null   float64
#  22  Female iliterates            82968 non-null   float64
#  23  Total main workers           132315 non-null  int64
#  24  Male main workers            132315 non-null  int64
#  25  Female main workers          132315 non-null  int64
#  26  Total non workers            132315 non-null  int64
#  27  Male non workers             132315 non-null  int64
#  28  Female non workers           132315 non-null  int64
# dtypes: float64(3), int64(23), object(3)
# memory usage: 29.3+ MB

# %% [markdown]
# # 2 . Data Cleaning

# %% [markdown]
# 2.1 Counting Missing Values in Each Columns

# %%
df.isnull().sum()
# Out:
# Census Year                        0
# District                           0
# Taluka                            16
# Town/Village                    1036
# No. of households                  0
# Total population                   0
# Total male population              0
# Total female population            0
# Total 0 to 6 year children         0
# Male 0 to 6 year children          0
# Female 0 to 6 year children        0
# Total SC population                0
# Male SC population                 0
# Female SC population               0
# Total ST population                0
# Male ST population                 0
# Female ST population               0
# Total literates                    0
# Male literates                     0
# Female literates                   0
# Total iliterates               49347
# Male iliterates                49347
# Female iliterates              49347
# Total main workers                 0
# Male main workers                  0
# Female main workers                0
# Total non workers                  0
# Male non workers                   0
# Female non workers                 0
# dtype: int64

# %% [markdown]
# Observation: Columns Containing Null Values are Total iliterates, iliterates and Female iliterates these null values can be fixed.

# %% [markdown]
# **2.2 Columns Containing Null Values**

# %%
missing_data = df.isna().any(axis=1)
df[missing_data]
# Out:
#         Census Year         District    Taluka  \
# 60285          2001           MUMBAI       NaN
# 60286          2001  MUMBAI SUBURBAN       NaN
# 82968          1991       AHMADNAGAR     AKOLA
# 82969          1991       AHMADNAGAR     AKOLA
# 82970          1991       AHMADNAGAR     AKOLA
# ...             ...              ...       ...
# 132310         1991         YAVATMAL  YAVATMAL
# 132311         1991         YAVATMAL  YAVATMAL
# 132312         1991         YAVATMAL  YAVATMAL
# 132313         1991         YAVATMAL  YAVATMAL
# 132314         1991         YAVATMAL  YAVATMAL
#
#                            Town/Village  No. of households  Total population  \
# 60285   GREATER MUMBAI (M CORP.) (PART)             677163           3338031
# 60286   GREATER MUMBAI (M CORP.) (PART)            1838426           8640419
# 82968                         08RANGPUR                145               819
# 82969                          2AMBHALE                162               797
# 82970                        ABIT KHIND                151               706
# ...                                 ...                ...               ...
# 132310                         YELABARA                489              2381
# 132311                            YERAD                234              1162
# 132312                           YEVATI                103               461
# 132313                             ZOLA                  0                 0
# 132314                             ZULI                124               592
#
#         Total male population  Total female population  \
# 60285                 1878246                  1459785
# 60286                 4741720                  3898699
# 82968                     390                      429
# 82969                     384                      413
# 82970                     342                      364
# ...                       ...                      ...
# 132310                   1237                     1144
# 132311                    588                      574
# 132312                    232                      229
# 132313                      0                        0
# 132314                    306                      286
#
#         Total 0 to 6 year children  Male 0 to 6 year children  ...  \
# 60285                       339723                     176789  ...
# 60286                      1024700                     532988  ...
# 82968                          150                         79  ...
# 82969                          154                         80  ...
# 82970                          120                         63  ...
# ...                            ...                        ...  ...
# 132310                         364                        175  ...
# 132311                         189                         94  ...
# 132312                          77                         37  ...
# 132313                           0                          0  ...
# 132314                          98                         52  ...
#
#         Female literates  Total iliterates  Male iliterates  \
# 60285            1055437          747418.0         343070.0
# 60286            2763888         2023155.0         888344.0
# 82968                173               NaN              NaN
# 82969                129               NaN              NaN
# 82970                 99               NaN              NaN
# ...                  ...               ...              ...
# 132310               417               NaN              NaN
# 132311               149               NaN              NaN
# 132312                53               NaN              NaN
# 132313                 0               NaN              NaN
# 132314                85               NaN              NaN
#
#         Female iliterates  Total main workers  Male main workers  \
# 60285            404348.0             1250710            1068656
# 60286           1134811.0             2971039            2524384
# 82968                 NaN                 382                188
# 82969                 NaN                 371                161
# 82970                 NaN                 421                210
# ...                   ...                 ...                ...
# 132310                NaN                1111                643
# 132311                NaN                 581                302
# 132312                NaN                 246                143
# 132313                NaN                   0                  0
# 132314                NaN                 341                185
#
#         Female main workers  Total non workers  Male non workers  \
# 60285                182054            2026292            766831
# 60286                446655            5487910           2088585
# 82968                   194                429               198
# 82969                   210                399               211
# 82970                   211                280               132
# ...                     ...                ...               ...
# 132310                  468               1249               588
# 132311                  279                559               283
# 132312                  103                204                87
# 132313                    0                  0                 0
# 132314                  156                242               120
#
#         Female non workers
# 60285              1259461
# 60286              3399325
# 82968                  231
# 82969                  188
# 82970                  148
# ...                    ...
# 132310                 661
# 132311                 276
# 132312                 117
# 132313                   0
# 132314                 122
#
# [49349 rows x 29 columns]

# %% [markdown]
# **2.3 From Above Code We can Conclude that Male illterates populations can be calculated by Total male population and Male literates**

# %%
df['Male iliterates'] = df['Total male population'] - df['Male literates']
df['Male iliterates'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **2.4 Following Similar Approach for Female iliterates**

# %%
df['Female iliterates'] =df['Total female population'] - df['Female literates']
df['Female iliterates'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **2.5 Calculating Total iliterate population**

# %%
df['Total iliterates'] = df['Male iliterates'] + df['Female iliterates']
df['Total iliterates'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **2.6 Dropping all the duplicate rows in dataset**

# %%
df.drop_duplicates()
df.shape
# Out:
# (132315, 29)

# %% [markdown]
# **2.7 Replacing all the Null Values to Zero**

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# #3 Exploratory Data Analysis

# %% [markdown]
# **3.1 Summarize the main Characterstics of the data**

# %%
df.describe()
# Out:
#          Census Year  No. of households  Total population  \
# count  132315.000000       1.323150e+05      1.323150e+05
# mean     2000.406492       8.222010e+02      4.144163e+03
# std         8.264585       1.213648e+04      5.730412e+04
# min      1991.000000       0.000000e+00      0.000000e+00
# 25%      1991.000000       1.020000e+02      4.930000e+02
# 50%      2001.000000       1.930000e+02      9.460000e+02
# 75%      2011.000000       3.610000e+02      1.785000e+03
# max      2011.000000       2.105604e+06      9.925891e+06
#
#        Total male population  Total female population  \
# count           1.323150e+05             1.323150e+05
# mean            2.156298e+03             1.987865e+03
# std             3.084739e+04             2.648095e+04
# min             0.000000e+00             0.000000e+00
# 25%             2.460000e+02             2.450000e+02
# 50%             4.780000e+02             4.680000e+02
# 75%             9.090000e+02             8.770000e+02
# max             5.460145e+06             4.465746e+06
#
#        Total 0 to 6 year children  Male 0 to 6 year children  \
# count                1.323150e+05              132315.000000
# mean                 6.286691e+02                 326.209719
# std                  7.273950e+03                3782.663981
# min                  0.000000e+00                   0.000000
# 25%                  7.300000e+01                  37.000000
# 50%                  1.440000e+02                  74.000000
# 75%                  2.730000e+02                 142.000000
# max                  1.340673e+06              698357.000000
#
#        Female 0 to 6 year children  Total SC population  Male SC population  \
# count                132315.000000        132315.000000       132315.000000
# mean                    302.459358           493.478041          253.877111
# std                    3491.664407          5835.730419         3014.781904
# min                       0.000000             0.000000            0.000000
# 25%                      35.000000             4.000000            2.000000
# 50%                      69.000000            73.000000           37.000000
# 75%                     131.000000           234.000000          119.000000
# max                  642316.000000        646914.000000       344085.000000
#
#        ...  Female literates  Total iliterates  Male iliterates  \
# count  ...      1.323150e+05      1.323150e+05     1.323150e+05
# mean   ...      1.125535e+03      1.467068e+03     6.047389e+02
# std    ...      1.845541e+04      1.482293e+04     6.500574e+03
# min    ...      0.000000e+00      0.000000e+00     0.000000e+00
# 25%    ...      8.800000e+01      2.050000e+02     7.800000e+01
# 50%    ...      2.020000e+02      4.040000e+02     1.570000e+02
# 75%    ...      4.290000e+02      7.740000e+02     3.070000e+02
# max    ...      3.352456e+06      2.811580e+06     1.247676e+06
#
#        Female iliterates  Total main workers  Male main workers  \
# count       1.323150e+05        1.323150e+05       1.323150e+05
# mean        8.623294e+02        1.405156e+03       1.047037e+03
# std         8.332743e+03        1.954535e+04       1.627014e+04
# min         0.000000e+00        0.000000e+00       0.000000e+00
# 25%         1.250000e+02        1.990000e+02       1.190000e+02
# 50%         2.460000e+02        4.090000e+02       2.390000e+02
# 75%         4.670000e+02        7.860000e+02       4.630000e+02
# max         1.563904e+06        3.515922e+06       2.966082e+06
#
#        Female main workers  Total non workers  Male non workers  \
# count        132315.000000       1.323150e+05      1.323150e+05
# mean            358.118626       2.586600e+03      1.044369e+03
# std            3359.076581       3.434923e+04      1.242163e+04
# min               0.000000       0.000000e+00      0.000000e+00
# 25%              70.000000       2.220000e+02      1.060000e+02
# 50%             166.000000       4.470000e+02      2.120000e+02
# 75%             324.000000       8.770000e+02      4.120000e+02
# max          704441.000000       5.621941e+06      2.088585e+06
#
#        Female non workers
# count        1.323150e+05
# mean         1.542231e+03
# std          2.290367e+04
# min          0.000000e+00
# 25%          1.130000e+02
# 50%          2.320000e+02
# 75%          4.680000e+02
# max          3.973736e+06
#
# [8 rows x 26 columns]

# %% [markdown]
# **3.2 Population Destribution**

# %% [markdown]
# 3.2.1 Population Distribution by District

# %%
#Filtering Data for Analysis
grouped_population_data = df.groupby('District')[['Total population','Total male population' , 'Total female population', ]].sum().sort_values(by='Total population',ascending=False)
plt.figure(figsize=(16,8))
sns.barplot(x='District',y='Total male population',data=grouped_population_data)
plt.grid()
plt.xticks(rotation=75)
plt.title('Population Distribution in Each District')
plt.xlabel('District')
plt.ylabel('Population')
plt.show()

# %% [markdown]
# **3.2.2 Gender Distribution**

# %%
gender_population_data = df.groupby('District')[['Total male population','Total female population']].sum().sort_values(by='Total male population',ascending=False)
gender_population_data.plot(kind= 'bar',figsize=(16,10),width = 0.8)
plt.xticks(rotation=75)
plt.title('Population Distribution by gender in Each District')
plt.xlabel('District')
plt.ylabel('Population')
plt.show()

# %% [markdown]
# **3.3 Gender Ratio Distribution**

# %% [markdown]
# **Overall Gender Ratio get decreased in Maharastra from year 1991 to 2011**

# %%
for index, row in df.iterrows():
    if (row['Total male population'] ==0):
        gender_population_data.loc[index, 'Gender Ratio'] = 0
    else:
      gender_population_data.loc[index, 'Gender Ratio'] = (row['Total female population']/row['Total male population'])*1000
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-d1d9d4cfdc6f> in <cell line: 1>()
#       3         gender_population_data.loc[index, 'Gender Ratio'] = 0
#       4     else:
# ----> 5       gender_population_data.loc[index, 'Gender Ratio'] = (row['Total female population']/row['Total male population'])*1000
#       6
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     847
#     848         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849         iloc._setitem_with_indexer(indexer, value, self.name)
#     850
#     851     def _validate_key(self, key, axis: AxisInt):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1833         if take_split_path:
#    1834             # We have to operate column-wise
# -> 1835             self._setitem_with_indexer_split_path(indexer, value, name)
#    1836         else:
#    1837             self._setitem_single_block(indexer, value, name)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1926             # scalar value
#    1927             for loc in ilocs:
# -> 1928                 self._setitem_single_column(loc, value, pi)
#    1929
#    1930     def _setitem_with_indexer_2d_value(self, indexer, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_single_column(self, loc, value, plane_indexer)
#    2032             # set value into the column (first attempting to operate inplace, then
#    2033             #  falling back to casting if necessary)
# -> 2034             self.obj._mgr.column_setitem(loc, plane_indexer, value)
#    2035
#    2036         self.obj._clear_item_cache()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in column_setitem(self, loc, idx, value, inplace_only)
#    1383         else:
#    1384             new_mgr = col_mgr.setitem((idx,), value)
# -> 1385             self.iset(loc, new_mgr._block.values, inplace=True)
#    1386
#    1387     def insert(self, loc: int, item: Hashable, value: ArrayLike) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _block(self)
#    1942         pass
#    1943
# -> 1944     @cache_readonly
#    1945     def _block(self) -> Block:
#    1946         return self.blocks[0]
#
# KeyboardInterrupt:

# %%
grouped_gender_ratio_data =  gender_population_data.groupby(df['Census Year'])['Gender Ratio'].mean()
grouped_gender_ratio_data
# Out:
# Census Year
# 1991.0    933.340337
# 2001.0    983.361217
# 2011.0    970.441169
# Name: Gender Ratio, dtype: float64

# %%
grouped_gender_ratio_data.plot(kind = 'line')
# Out:
# <Axes: xlabel='Census Year'>

# %% [markdown]
# **3.4 Litracy Ratio**

# %%
#Calculating Litracy Rate
gender_litracy_data = pd.DataFrame(df[['Census Year','District', 'Male literates','Female literates','Total male population','Total female population']])
gender_litracy_data['female_literate_population %']  = ((df['Female literates']/df['Total female population'])*100).round(2)
gender_litracy_data['male_literate_population %']  = ((df['Male literates']/df['Total male population'])*100).round(2)
gender_litracy_data['total_literate_population %']  =((df['Total literates']/df['Total population'])*100).round(2)

gender_litracy_data.groupby('District')['total_literate_population %'].mean()
# Out:
# District
# AHMADNAGAR         56.647979
# AKOLA              59.530362
# AMRAVATI           61.341806
# AURANGABAD         51.266640
# BEED               58.706783
# BHANDARA           58.216627
# BID                35.991114
# BULDANA            58.033859
# CHANDRAPUR         54.704419
# DHULE              41.127284
# GADCHIROLI         39.089512
# GONDIYA            68.508820
# GREATER BOMBAY     71.670000
# HINGOLI            58.783900
# JALGAON            55.875314
# JALNA              47.118373
# KOLHAPUR           58.912925
# LATUR              54.460944
# MUMBAI             79.465000
# MUMBAI SUBURBAN    78.770000
# NAGPUR             59.821656
# NANDED             49.074480
# NANDURBAR          43.353890
# NASHIK             51.307175
# OSMANABAD          54.110757
# PARBHANI           44.971970
# PUNE               57.678192
# RAIGARH            58.475586
# RATNAGIRI          61.332958
# SANGLI             59.007108
# SATARA             61.891250
# SINDHUDURG         70.584712
# SOLAPUR            53.399825
# THANE              50.199766
# WARDHA             63.054949
# WASHIM             65.106207
# YAVATMAL           56.561706
# Name: total_literate_population %, dtype: float64

# %% [markdown]
# **3.5 District with height Litracy rate**

# %%
district_litracy_data = gender_litracy_data.groupby('District')['total_literate_population %'].mean().sort_values(ascending=False).head(11)

# %%
district_litracy_bar = district_litracy_data.plot(kind='bar',figsize=(16,8),width = 0.8 , color = '#ff6361')
plt.xticks(rotation=45)
plt.grid(True)
plt.title('Top Most Literate Districts in MHA with Litracy rate above 60%')
plt.xlabel('MHA Districts')
plt.ylabel('Total literate population in %')
plt.ylim(60,90)
for bar in district_litracy_bar.patches:
    district_litracy_bar.annotate(str(round(bar.get_height(),2))+'%', (bar.get_x() , bar.get_height()))
plt.show()

# %% [markdown]
# **3.6 Male and Female Litracy Comparison**

# %%
female_litracy_data = gender_litracy_data.groupby('District')[['female_literate_population %','male_literate_population %']].mean().sort_values(by='female_literate_population %',ascending=True)
female_litracy_data.plot(kind='bar',figsize=(16,8),width = 0.8,color =['#003f5c','#f95d6a'])
plt.title('Male and Female Litracy Comparison')
plt.grid(True)
plt.xticks(rotation=75)
plt.xlabel('MHA Districts')
plt.ylabel('Total literate population in %')
plt.ylim(20,90)
plt.show()

# %% [markdown]
# **3.7 Overall Male and  Female Litracy Rate Over the Census Year**

# %%
female_litracy_data_census = df.groupby('Census Year')[['Female literates','Male literates']].sum()
bar_plot_female_litracy = female_litracy_data_census.plot(kind='bar',figsize=(16,8),width = 0.5)
plt.title('Overall Male and Female Litracy for  the Census Years')
plt.xticks(rotation=360)
plt.xlabel('Census Year')
plt.ylabel('Total literate population in million')
plt.show()

# %% [markdown]
# **3.8 Corelation betwen litracy and population**

# %%
pair_wise_correlation = df[['Male literates','Male iliterates','Female literates','Female iliterates','Total population']].corr()
sns.heatmap(pair_wise_correlation,annot=True)
plt.show()

# %% [markdown]
# **3.9 Male and Female Population non working population**

# %%
df.groupby('Census Year')[['Male non workers','Female non workers']].sum().plot(kind='bar',figsize=(16,8),width = 0.8 ,color=["#27aeef", "#b33dc6"])
plt.title('Male and Female Population non working population')
plt.xticks(rotation=360)
plt.xlabel('Census Year')
plt.ylabel('Population in million')
plt.show()
